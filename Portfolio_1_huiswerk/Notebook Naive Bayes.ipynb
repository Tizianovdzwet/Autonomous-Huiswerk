# %% [markdown]
# ## Data inladen

# %% [markdown]
# De data bestaat uit SMS berichten met een label of het bericht spam is of niet. We gaan de data inladen en bekijken.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

np.random.seed(123)

data = pd.read_csv('spam.csv', encoding='latin-1')

X = data['v2']
y = data['v1']

vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X).toarray()

X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

display(data)
display(X_vectorized.shape)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %% [markdown]
# ## Naive Bayes met SKLearn
# ### Model trainen
# Gebruik de `MultinomialNB` class van SKLearn om een Naive Bayes model te trainen op `X_train` en `y_train`. Evalueer het model op `X_test` en `y_test` en print de accuracy.

# %%
from sklearn.naive_bayes import MultinomialNB

nb_classifier = MultinomialNB()
# Antwoord: 
# ...
# Out:
# Accuracy: 0.97847533632287

# %% [markdown]
# ## Genereer voorspellingen

# %% [markdown]
# Nu gaan we het getrainde model gebruiken om nieuwe data te genereren. Er ontbreekt een regel code die je moet invullen. Gebruik de methode `np.random.choice`.

# %%
aantal_woorden = 20
type = 1 # 0 = ham, 1 = spam

feature_probs = nb_classifier.feature_log_prob_[type]

woorden = []
for _ in range(aantal_woorden):
    word_index = # Antwoord ...

    word = vectorizer.get_feature_names_out()[word_index]
    woorden.append(word)

print(' '.join(woorden))
# Out:
# pretsovru dehydration chess lyfu ratio guy woulda popped invoices function evening reffering help08714742804 402 gay request book bk likely liking

# %% [markdown]
# # Naive Bayes zelf trainen

# %% [markdown]
# ## Model trainen
# In de onderstaande code ontbreekt een regel code die je moet invullen. Gebruik de formules voor Naive Bayes om de likelihood te berekenen.

# %%
classes = np.unique(y_train)
class_prior = {c: np.mean(y_train == c) for c in classes}
feature_likelihood = {}

for c in classes:
    X_c = X_train[y_train == c]
    feature_likelihood[c] = (X_c.sum(axis=0) + 1) / (X_c.sum() + X_train.shape[1])

predictions = []
for x in X_test:
    class_posteriors = {}
    for c in classes:
        prior = class_prior[c]
        likelihood = # Antwoord...
        class_posteriors[c] = prior * likelihood
    predictions.append(max(class_posteriors, key=class_posteriors.get))

accuracy_scratch = accuracy_score(y_test, np.array(predictions))
print(f'Accuracy (from scratch): {accuracy_scratch}')
# Out:
# Accuracy (from scratch): 0.97847533632287
