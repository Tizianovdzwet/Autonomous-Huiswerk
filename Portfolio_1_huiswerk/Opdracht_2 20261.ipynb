# %% [markdown]
# ## Opdracht : Game Theory - Mixed Strategy Nash Equilibriums
#
# 1. **Theorievragen:**
#    - Wat is een mixed strategie Nash equilibrium?
#
#    Dit is een situatie waar spelers een keuze maken op basis van een waarschijnlijkheid verdeling
#
#    - Beschrijf het verschil tussen pure strategie Nash equilibria en mixed strategie Nash equilibria.
#
#    De ene is een keuze met zekerheid de andere is gerandomized
#
#    - Leg uit wat een Linear Complementarity Problem (LCP) is.
#
#    is een wiskundig probleem dat de relatie tussen twee variabelen beschrijft die elkaar "uitsluiten". Het is geen standaard vergelijking (zoals $1 + 1 = 2$), maar een set regels die bepalen hoe systemen met harde grenzen zich gedragen.
#
# 2. **Praktische Oefening:**  Marketing Strategie
#   - **A)** Twee concurrerende bedrijven, A en B, moeten elk uur een marketingstrategie kiezen: een kortingsactie of een online advertentiecampagne. De effectiviteit van elke strategie hangt af van de keuze van de concurrent. Als beide bedrijven dezelfde strategie gebruiken, delen ze de marktvoordelen. Als ze verschillende strategieën kiezen, profiteert het ene bedrijf meer afhankelijk van de gekozen strategieën. Bedrijven willen een strategische mix vinden om onvoorspelbaar te blijven en hun marktaandeel te maximaliseren.
#     ```
#        |                     | Kortingsactie | Online Advertentie |
#        |---------------------|---------------|--------------------|
#        | Kortingsactie       | (40, 40)      | (10, 20)           |
#        | Online Advertentie  | (20, 10)      | (30, 30)           |
#     ```
#      **Opdracht:** Bereken het mixed strategie Nash equilibrium voor dit spel.
#      up-down of left-right
#
#   - **B)** Zijn er nog andere Nash Equilibria?
#   Ja boven -links en under - rechts
#   - **C)** Gebruik https://nashpy.readthedocs.io/en/v0.0.33/ om het boven verkregen antwoord te controleren.

# %% [markdown]
# 3. **Steen, Papier Schaar**
#   - **A)** In een spel "Steen, Papier, Schaar" spelen twee spelers een aangepaste versie met de volgende regels:
#
#   **Acties:** Beide spelers kiezen uit *Steen*, *Papier* of *Schaar*.
#
#   **Puntentelling:**
#    - Als een speler wint met *Steen*, krijgt hij/zij **2 punten** in plaats van 1.
#    - Overwinningen met *Papier* en *Schaar* blijven 1 punt waard.
#    - Bij een gelijkspel krijgt elke speler **0 punten**.
#
# |               | Steen       | Papier  |  Schaar |
# |---------------|-------------|---------|---------|
# | **Steen**     | (0, 0)      | (2, -1) | (-1, 1) |
# | **Papier**    | (-1, 2)     | (0, 0)  | (1, -1) |
# | **Schaar**    | (1, -1)     | (-1, 1) | (0, 0)  |
#
#
#   **Opdracht:** Bepaal het **Mixed Strategy Nash Equilibrium** voor dit spel.
#
#   - **B)** Gebruik https://nashpy.readthedocs.io/en/v0.0.33/ om het hierboven gekregen antwoord te controleren.

# %%
## YOUR CODE HERE
